# %%
# %run script.py

# %%
import pandas as pd
import csv

# For connect to google sheet
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# %%
# Configure the connection 
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/drive']

# Give the path to the Service Account Credential json file 
credentials = ServiceAccountCredentials.from_json_keyfile_name('/Users/chris.trauco/.config/gspread/service_account.json', scope)
# Authorise your Notebook
gc = gspread.authorize(credentials)

# %%
file = 'okta-dump-20230216143011'

# %%
# No. 1
#group_users
# https://docs.google.com/spreadsheets/d/1nP_5hWxHV2NcTfEwXjVhnhxEV125ZQfGVQaKygoumAg/edit#gid=1427211788
# ss id
# The sprad sheet ID, which can be taken from the link to the sheet
spreadsheet_key = '1nP_5hWxHV2NcTfEwXjVhnhxEV125ZQfGVQaKygoumAg'

# csv to df
data = f'{file}/group_users.csv'
df = pd.read_csv(data)

# dataframe to list of lists
x = df.values.tolist()

# match user okta ID(second list element) to group, first list element into python dictionary
result = {} # empty dictionary
for li in x:
    result.setdefault(li[0],[]).append(li[1])
# print(result)

#orient index to group id
output = pd.DataFrame.from_dict(result,orient="index")


cleanup = output.fillna("")
cleanup.reset_index(drop=True)

df2 = cleanup
df2['groups'] = df2.index

df2.reset_index(drop=True)

df3 = df2['groups']

cleanup['users'] = cleanup.values.tolist()


# cleanup['users'] = cleanup['users'].str.strip()
# cleanup = cleanup.fillna("")



df4 = cleanup['users']
# users = cleanup

df4['cols'] = df4.index
df4.reset_index(drop=True)


df5 = df4.to_frame()
df5['groups'] = df2['groups']

# df5 = df5.pop('groups')



print(df5)
# Set the sheet name you want to upload data to and the start cell where the upload data begins 
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(df5,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')

# %%
##### Okta App Users

# https://docs.google.com/spreadsheets/d/1_Z7NKyuxHwCLe3BBYnc1lVVbuAOmHsRoBm9a1KzIC_o/edit#gid=0
spreadsheet_key = "1v3onC_tAAEauzVI8GPucefT4PmuXBUb7dlSUzLiFV9o"

# csv to df
data = f"{file}/app_users.csv"
df = pd.read_csv(data)

# print(df)

# dataframe to list of lists
x = df.values.tolist()
result = {} # empty dictionary
for li in x:
    result.setdefault(li[0],[]).append(li[1])
# print(result)




output = pd.DataFrame.from_dict(result,orient="index")
cleanup = output.fillna("None")
cleanup.reset_index(inplace=True)


df2 = cleanup
df2['apps'] = df2.index

df2.reset_index(drop=True)

df3 = df2['apps']

cleanup['users'] = cleanup.values.tolist()








df4 = cleanup['users']
# users = cleanup

df4['cols'] = df4.index
df4.reset_index(drop=True)


df5 = df4.to_frame()

# df5 = df5.pop('groups')



print(df5)
# Set the sheet name you want to upload data to and the start cell where the upload data begins 



wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(df5,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')
# Out:
# /var/folders/ws/t0k8pbks0lq4swlyt12h4ptc0000gp/T/ipykernel_1814/4073178065.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cleanup.reset_index(inplace=True)
# /var/folders/ws/t0k8pbks0lq4swlyt12h4ptc0000gp/T/ipykernel_1814/4073178065.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2['apps'] = df2.index
# /var/folders/ws/t0k8pbks0lq4swlyt12h4ptc0000gp/T/ipykernel_1814/4073178065.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#orient index to group id
output = pd.DataFrame.from_dict(result,orient="index")


cleanup = output.fillna("")
cleanup.reset_index(drop=True)

df2 = cleanup
df2['groups'] = df2.index

df2.reset_index(drop=True)

df3 = df2['groups']

cleanup['users'] = cleanup.values.tolist()


# cleanup['users'] = cleanup['users'].str.strip()
# cleanup = cleanup.fillna("")



df4 = cleanup['users']
# users = cleanup

df4['cols'] = df4.index
df4.reset_index(drop=True)


df5 = df4.to_frame()
df5['groups'] = df2['groups']

# df5 = df5.pop('groups')



print(df5)
# Set the sheet name you want to upload data to and the start cell where the upload data begins 
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(df5,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')

# %%
##### Okta User Apps

# https://docs.google.com/spreadsheets/d/1m8vQ9kcGhayXn0AifcsZK2s21OhVPnStmyJ2Vu_h128/edit#gid=1556046511
spreadsheet_key = "1m8vQ9kcGhayXn0AifcsZK2s21OhVPnStmyJ2Vu_h128"

# csv to df
data = f"{file}/app_users.csv"
df = pd.read_csv(data)

# print(df)

# new df for user apps columns

df = df.filter(['user','app'], axis=1)
# print(df)

# dataframe to list of lists
x = df.values.tolist()
result = {} # empty dictionary
for li in x:
    result.setdefault(li[0],[]).append(li[1])
# print(result)
output = pd.DataFrame.from_dict(result,orient="index")
cleanup = output.fillna("")
df = pd.concat(axis=1)
print(df)
# cleanup.reset_index(inplace=True)

# print(cleanup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 25
#      23 output = pd.DataFrame.from_dict(result,orient="index")
#      24 cleanup = output.fillna("")
# ---> 25 df = pd.concat(axis=1)
#      26 print(df)
#      27 # cleanup.reset_index(inplace=True)
#      28
#      29 # print(cleanup)
#
# File ~/dev-color/okta/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# TypeError: concat() missing 1 required positional argument: 'objs'

# %%
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(cleanup,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')

# %%
output = pd.DataFrame.from_dict(result,orient="index")
cleanup = output.fillna("")
cleanup.reset_index(inplace=True)

# print(cleanup)

wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(cleanup,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')

# %%
# # No. 3
# # Okta User Apps
# # https://docs.google.com/spreadsheets/d/1vdU6sbAH-fTsLSd4V_JbcRG4rfUHa909fMjhwBTnwgE/edit#gid=0
# spreadsheet_key = '1_Z7NKyuxHwCLe3BBYnc1lVVbuAOmHsRoBm9a1KzIC_o'


# # csv to df
# data = f'{file}/app_users.csv'
# df = pd.read_csv(data)

# # dataframe to list of lists
# x = df.values.tolist()

# # match user okta ID(second list element) to group, first list element into python dictionary
# result = {} # empty dictionary
# for li in x:
#     result.setdefault(li[0],[]).append(li[1])
# # print(result)

# #orient index to group id
# output = pd.DataFrame.from_dict(result)

# cleanup = output.fillna("")

# # test output
# # Set the sheet name you want to upload data to and the start cell where the upload data begins 
# wks_name = 'Data'
# cell_of_start_df = 'A1'
# # upload the dataframe of the clients we want to delete
# d2g.upload(cleanup,
#            spreadsheet_key,
#            wks_name,
#            credentials=credentials,
#            col_names=True,
#            row_names=False,
#            start_cell = cell_of_start_df,
#            clean=True)
# print ('The sheet is updated successfully')

# %%
######## OKTA USERS
# ss id
# The sprad sheet ID, which can be taken from the link to the sheet
spreadsheet_key = '1XEaa9njfMYcWYgP0P074d59JRg-4YsYb8KljccEm6os'

# csv to df
data = f"{file}/users.csv"
df = pd.read_csv(data)

# dataframe to list of lists
x = df.values.tolist()

#orient index to group id
output = pd.DataFrame.from_dict(x)

cleanup = output.fillna("")

# test output
# Set the sheet name you want to upload data to and the start cell where the upload data begins 
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(cleanup,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')

# %%
# OKTA Apps
# https://docs.google.com/spreadsheets/d/13PXcQOUXcJ2hxjxgTFt9_CZLb26wvBTRbIKlPwDq3_c/edit#gid=1427211788
spreadsheet_key = '13PXcQOUXcJ2hxjxgTFt9_CZLb26wvBTRbIKlPwDq3_c'

# csv to df
data = f"{file}/apps.csv"
df = pd.read_csv(data)

# dataframe to list of lists
x = df.values.tolist()

#orient index to group id
output = pd.DataFrame.from_dict(x)

cleanup = output.fillna("")

# test output
# Set the sheet name you want to upload data to and the start cell where the upload data begins 
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(cleanup,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')
# Out:
# The sheet is updated successfully

# %%
# OKTA Apps
# https://docs.google.com/spreadsheets/d/13PXcQOUXcJ2hxjxgTFt9_CZLb26wvBTRbIKlPwDq3_c/edit#gid=1427211788
spreadsheet_key = '16KWOOPBq5Woktey0baelXOAUpSMgWgirCIIczMFg864'

# csv to df
data = f"{file}/groups.csv"
df = pd.read_csv(data)

# dataframe to list of lists
x = df.values.tolist()

#orient index to group id
output = pd.DataFrame.from_dict(x)

cleanup = output.fillna("")

# test output
# Set the sheet name you want to upload data to and the start cell where the upload data begins 
wks_name = 'Data'
cell_of_start_df = 'A1'
# upload the dataframe of the clients we want to delete
d2g.upload(cleanup,
           spreadsheet_key,
           wks_name,
           credentials=credentials,
           col_names=True,
           row_names=False,
           start_cell = cell_of_start_df,
           clean=True)
print ('The sheet is updated successfully')
# Out:
# The sheet is updated successfully

# %%
# Access Review Workbook
# https://docs.google.com/spreadsheets/d/1YFusG-AQvkwKLqtVLYqTh0eyeXUUOijNQT57Xad5wfI/edit#gid=150230516

# %%
df['ColumnA'] = output[output.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df
# Out:
#                       group                  user ColumnA
# 0      00g7z490sgAG8DSPW2p7  00u1z8o6suxbgndrM2p7     NaN
# 1      00g7z490sgAG8DSPW2p7  00u1z8p65g3x4O3DZ2p7     NaN
# 2      00g7z490sgAG8DSPW2p7  00u1z8qax69Z7JpMa2p7     NaN
# 3      00g7z490sgAG8DSPW2p7  00u2xgdajhyuPvF0T2p7     NaN
# 4      00g7z490sgAG8DSPW2p7  00u34dmwu6AxWGBzW2p7     NaN
# ...                     ...                   ...     ...
# 28369  00gjfixga6q1PkFYH2p7  00uannx44oyB9abA52p7     NaN
# 28370  00gjfixga6q1PkFYH2p7  00uaou7oh3V2RTz792p7     NaN
# 28371  00gjfixga6q1PkFYH2p7  00udtgyhqyvw4cPjN2p7     NaN
# 28372  00gjfixga6q1PkFYH2p7  00ugbo9lniEn9j8ZN2p7     NaN
# 28373  00gjfixga6q1PkFYH2p7  00ugo1f3izrZba6pz2p7     NaN
#
# [28374 rows x 3 columns]
